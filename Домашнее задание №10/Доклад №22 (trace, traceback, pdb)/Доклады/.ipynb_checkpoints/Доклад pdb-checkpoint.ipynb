# %% [markdown]
# # PDB

# %% [markdown]
# https://pymotw.com/3/pdb/index.html

# %% [markdown]
# Модуль pdb использует специальные функции интерпретатора Python для реализации простого интерактивного отладчика командной строки. С его помощью вы сможете задавать точки останова, исполнять инструкции исходного код в пошаговом режиме, исследовать кадры стека и т.п.

# %% [markdown]
# Чтобы запустить отладчик из самой программы, необходимо использовать функцию pdb.set_trace()

# %%
import pdb

def hello(name):
    return "hello " + name
if __name__ == "__main__":
    hello(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-914a8af37691> in <module>
#       4     return "hello " + name
#       5 if __name__ == "__main__":
# ----> 6     hello(name)
#
# NameError: name 'name' is not defined

# %% [markdown]
# Очевидно у нас тут ошибка

# %% [markdown]
# Запускаем отладчик после ошибки с помощью pdb.pm()

# %%
pdb.pm()
# Out:
# > <ipython-input-1-914a8af37691>(6)<module>()
#       2
#       3 def hello(name):
#       4     return "hello " + name
#       5 if __name__ == "__main__":
# ----> 6     hello(name)
# ipdb>  h
# Documented commands (type help <topic>):
# ========================================
# EOF    cl         disable  interact  next    psource  rv           undisplay
# a      clear      display  j         p       q        s            unt
# alias  commands   down     jump      pdef    quit     skip_hidden  until
# args   condition  enable   l         pdoc    r        source       up
# b      cont       exit     list      pfile   restart  step         w
# break  continue   h        ll        pinfo   return   tbreak       whatis
# bt     d          help     longlist  pinfo2  retval   u            where
# c      debug      ignore   n         pp      run      unalias
#
# Miscellaneous help topics:
# ==========================
# exec  pdb
# ipdb>  q

# %% [markdown]
# Также можно запускать отладчик внутри программы.

# %%
import pdb

class MyObj:

    def __init__(self, num_loops):
        self.count = num_loops

    def go(self):
        for i in range(self.count):
            pdb.set_trace()
            print(i)
        return

if __name__ == '__main__':
    MyObj(5).go()
# Out:
# > <ipython-input-3-63e69efb3106>(11)go()
#       9         for i in range(self.count):
#      10             pdb.set_trace()
# ---> 11             print(i)
#      12         return
#      13
# ipdb>  h
# Documented commands (type help <topic>):
# ========================================
# EOF    cl         disable  interact  next    psource  rv           undisplay
# a      clear      display  j         p       q        s            unt
# alias  commands   down     jump      pdef    quit     skip_hidden  until
# args   condition  enable   l         pdoc    r        source       up
# b      cont       exit     list      pfile   restart  step         w
# break  continue   h        ll        pinfo   return   tbreak       whatis
# bt     d          help     longlist  pinfo2  retval   u            where
# c      debug      ignore   n         pp      run      unalias
#
# Miscellaneous help topics:
# ==========================
# exec  pdb
# ipdb>  q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-3-63e69efb3106> in <module>
#      13
#      14 if __name__ == '__main__':
# ---> 15     MyObj(5).go()
#
# <ipython-input-3-63e69efb3106> in go(self)
#       9         for i in range(self.count):
#      10             pdb.set_trace()
# ---> 11             print(i)
#      12         return
#      13
#
# <ipython-input-3-63e69efb3106> in go(self)
#       9         for i in range(self.count):
#      10             pdb.set_trace()
# ---> 11             print(i)
#      12         return
#      13
#
# ~\anaconda3\lib\bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# ~\anaconda3\lib\bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:

# %% [markdown]
# # Основные функции отладчика:

# %% [markdown]
# Next(n) - следующая строка

# %% [markdown]
# Step (s) - То же, что и next, но он будет заходить в функции, циклы, условия и т. д.

# %% [markdown]
# Until(unt) - переход к следующей строке, но обязательно чтоб номер следующей строки был больше предыдущего (актуально для циклов и т.д)

# %% [markdown]
# Down(d) или up(u) - позволяют передвигаться по стэк-фрейму до нового и старого фрейма

# %%
MyObj(5).go()
# Out:
# > <ipython-input-28-63e69efb3106>(11)go()
#       9         for i in range(self.count):
#      10             pdb.set_trace()
# ---> 11             print(i)
#      12         return
#      13
# ipdb>  next
# 0
# > <ipython-input-28-63e69efb3106>(9)go()
#       7
#       8     def go(self):
# ----> 9         for i in range(self.count):
#      10             pdb.set_trace()
#      11             print(i)
# ipdb>  s
# > <ipython-input-28-63e69efb3106>(10)go()
#       8     def go(self):
#       9         for i in range(self.count):
# ---> 10             pdb.set_trace()
#      11             print(i)
#      12         return
# ipdb>  next
# > <ipython-input-28-63e69efb3106>(11)go()
#       9         for i in range(self.count):
#      10             pdb.set_trace()
# ---> 11             print(i)
#      12         return
#      13
# ipdb>  until
# 1
# > <ipython-input-28-63e69efb3106>(11)go()
#       9         for i in range(self.count):
#      10             pdb.set_trace()
# ---> 11             print(i)
#      12         return
#      13
# ipdb>  next
# 2
# > <ipython-input-28-63e69efb3106>(9)go()
#       7
#       8     def go(self):
# ----> 9         for i in range(self.count):
#      10             pdb.set_trace()
#      11             print(i)
# ipdb>  until
# > <ipython-input-28-63e69efb3106>(10)go()
#       8     def go(self):
#       9         for i in range(self.count):
# ---> 10             pdb.set_trace()
#      11             print(i)
#      12         return
# ipdb>  d
# *** Newest frame
# ipdb>  q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-34-2c0b9fad3c48> in <module>
# ----> 1 MyObj(5).go()
#
# <ipython-input-28-63e69efb3106> in go(self)
#       8     def go(self):
#       9         for i in range(self.count):
# ---> 10             pdb.set_trace()
#      11             print(i)
#      12         return
#
# <ipython-input-28-63e69efb3106> in go(self)
#       8     def go(self):
#       9         for i in range(self.count):
# ---> 10             pdb.set_trace()
#      11             print(i)
#      12         return
#
# ~\anaconda3\lib\bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# ~\anaconda3\lib\bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:

# %% [markdown]
# # Функции для просмотра кода:

# %% [markdown]
# List(l) - Выводит 10 строк(или меньше, если код меньше) по 5 над и под строкой действия.

# %% [markdown]
# Longlist(ll) - Выводит весь код

# %% [markdown]
# Where (w) - показывает наше местоположение (не в жизни..)

# %%
MyObj(5).go()
# Out:
# > <ipython-input-28-63e69efb3106>(11)go()
#       9         for i in range(self.count):
#      10             pdb.set_trace()
# ---> 11             print(i)
#      12         return
#      13
# ipdb>  l
#       6         self.count = num_loops
#       7
#       8     def go(self):
#       9         for i in range(self.count):
#      10             pdb.set_trace()
# ---> 11             print(i)
#      12         return
#      13
#      14 if __name__ == '__main__':
#      15     MyObj(5).go()
# ipdb>  ll
#       8     def go(self):
#       9         for i in range(self.count):
#      10             pdb.set_trace()
# ---> 11             print(i)
#      12         return
#      13
# ipdb>  w
#     [... skipping 27 hidden frame(s)]
#
#   <ipython-input-35-2c0b9fad3c48>(1)<module>()
# ----> 1 MyObj(5).go()
#
# > <ipython-input-28-63e69efb3106>(11)go()
#       9         for i in range(self.count):
#      10             pdb.set_trace()
# ---> 11             print(i)
#      12         return
#      13
# ipdb>  q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-35-2c0b9fad3c48> in <module>
# ----> 1 MyObj(5).go()
#
# <ipython-input-28-63e69efb3106> in go(self)
#       9         for i in range(self.count):
#      10             pdb.set_trace()
# ---> 11             print(i)
#      12         return
#      13
#
# <ipython-input-28-63e69efb3106> in go(self)
#       9         for i in range(self.count):
#      10             pdb.set_trace()
# ---> 11             print(i)
#      12         return
#      13
#
# ~\anaconda3\lib\bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# ~\anaconda3\lib\bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:

# %% [markdown]
# Args (a) -  позваляет узнать аргумент функции

# %% [markdown]
# Retval(rv) - возвращает значение функции

# %% [markdown]
# whatis - выводит тип объекта

# %%
MyObj(5).go()
# Out:
# > <ipython-input-2-63e69efb3106>(11)go()
#       9         for i in range(self.count):
#      10             pdb.set_trace()
# ---> 11             print(i)
#      12         return
#      13
# ipdb>  args
# self = <__main__.MyObj object at 0x000001BAA9294C40>
# ipdb>  rv
# *** Not yet returned!
# ipdb>  whatis 123
# <class 'int'>
# ipdb>  whatis "qwe"
# <class 'str'>
# ipdb>  whatis hello
# Function hello
# ipdb>  q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-7-2c0b9fad3c48> in <module>
# ----> 1 MyObj(5).go()
#
# <ipython-input-2-63e69efb3106> in go(self)
#       9         for i in range(self.count):
#      10             pdb.set_trace()
# ---> 11             print(i)
#      12         return
#      13
#
# <ipython-input-2-63e69efb3106> in go(self)
#       9         for i in range(self.count):
#      10             pdb.set_trace()
# ---> 11             print(i)
#      12         return
#      13
#
# ~\anaconda3\lib\bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# ~\anaconda3\lib\bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:

# %% [markdown]
# display - позволяет следить за переменной по шагам

# %%
def recurse(level):
    print('recurse({})'.format(level))
    pdb.set_trace()
    
    if level:
        recurse(level - 1)

# %%
recurse(3)
# Out:
# recurse(3)
# > <ipython-input-16-3c2f94728406>(5)recurse()
#       2     print('recurse({})'.format(level))
#       3     pdb.set_trace()
#       4
# ----> 5     if level:
#       6         recurse(level - 1)
# ipdb>  display level
# display level: 3
# ipdb>  next
# > <ipython-input-16-3c2f94728406>(6)recurse()
#       2     print('recurse({})'.format(level))
#       3     pdb.set_trace()
#       4
#       5     if level:
# ----> 6         recurse(level - 1)
# ipdb>  next
# recurse(2)
# > <ipython-input-16-3c2f94728406>(5)recurse()
#       2     print('recurse({})'.format(level))
#       3     pdb.set_trace()
#       4
# ----> 5     if level:
#       6         recurse(level - 1)
# ipdb>  display level
# display level: 2
# ipdb>  undisplay
# ipdb>  q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-20-c99217d4b0b8> in <module>
# ----> 1 recurse(3)
#
# <ipython-input-16-3c2f94728406> in recurse(level)
#       4
#       5     if level:
# ----> 6         recurse(level - 1)
#
# <ipython-input-16-3c2f94728406> in recurse(level)
#       3     pdb.set_trace()
#       4
# ----> 5     if level:
#       6         recurse(level - 1)
#
# <ipython-input-16-3c2f94728406> in recurse(level)
#       3     pdb.set_trace()
#       4
# ----> 5     if level:
#       6         recurse(level - 1)
#
# ~\anaconda3\lib\bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# ~\anaconda3\lib\bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:

# %% [markdown]
# # Точки останова

# %% [markdown]
# Точки останова, или же breakpoints. Они нужны, чтобы мы могли переходить по разным кусочкам кода

# %% [markdown]
# break(b) - позволяет создавать точки останова

# %% [markdown]
# continue(c) - позволяет нам двигаться по коду исключительно по точкам останова

# %% [markdown]
# clear(cl) - удаляет 1 или все точки останова

# %% [markdown]
# commands - позволяет выполнить какую-то команду после перехода на точку останова

# %%
MyObj(5).go()
# Out:
# > <ipython-input-2-63e69efb3106>(11)go()
#       9         for i in range(self.count):
#      10             pdb.set_trace()
# ---> 11             print(i)
#      12         return
#      13
# ipdb>  q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-17-2c0b9fad3c48> in <module>
# ----> 1 MyObj(5).go()
#
# <ipython-input-2-63e69efb3106> in go(self)
#       9         for i in range(self.count):
#      10             pdb.set_trace()
# ---> 11             print(i)
#      12         return
#      13
#
# <ipython-input-2-63e69efb3106> in go(self)
#       9         for i in range(self.count):
#      10             pdb.set_trace()
# ---> 11             print(i)
#      12         return
#      13
#
# ~\anaconda3\lib\bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# ~\anaconda3\lib\bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:

# %% [markdown]
# # Jump (j) - "прыжок" на нужную строку

# %%
MyObj(5).go()
# Out:
# > <ipython-input-2-63e69efb3106>(11)go()
#       9         for i in range(self.count):
#      10             pdb.set_trace()
# ---> 11             print(i)
#      12         return
#      13
# ipdb>  j 9
# > <ipython-input-2-63e69efb3106>(9)go()
#       7
#       8     def go(self):
# ----> 9         for i in range(self.count):
#      10             pdb.set_trace()
#      11             print(i)
# ipdb>  j 12
# > <ipython-input-2-63e69efb3106>(12)go()
#      10             pdb.set_trace()
#      11             print(i)
# ---> 12         return
#      13
#      14 if __name__ == '__main__':
# ipdb>  q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-19-2c0b9fad3c48> in <module>
# ----> 1 MyObj(5).go()
#
# <ipython-input-2-63e69efb3106> in go(self)
#      10             pdb.set_trace()
#      11             print(i)
# ---> 12         return
#      13
#      14 if __name__ == '__main__':
#
# <ipython-input-2-63e69efb3106> in go(self)
#      10             pdb.set_trace()
#      11             print(i)
# ---> 12         return
#      13
#      14 if __name__ == '__main__':
#
# ~\anaconda3\lib\bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# ~\anaconda3\lib\bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:

# %% [markdown]
# # Print (p) и PreatyPrint(pp)

# %%
dictt = {'Names': ["Name1", "Name2", "Name3"], "Surnames": ["Surname1", "Surname2", "Surname3"]}

# %%
pdb.pm()
# Out:
# > <ipython-input-50-8ea6b96075bd>(1)<module>()
# ----> 1 python -m ;pdb
# ipdb>  p dictt
# {'Names': ['Name1', 'Name2', 'Name3'], 'Surnames': ['Surname1', 'Surname2', 'Surname3']}
# ipdb>  pp dictt
# {'Names': ['Name1', 'Name2', 'Name3'],
#  'Surnames': ['Surname1', 'Surname2', 'Surname3']}
# ipdb>  q

# %% [markdown]
# Функция runcall() модуля pdb вызывает функцию с заданными аргументами

# %%
def pluss(a,b):
    print(a+b)

# %%
pdb.runcall(pluss,5,10)
# Out:
# > <ipython-input-70-7c7ba2c47d3e>(2)pluss()
#       1 def pluss(a,b):
# ----> 2     print(a+b)
# ipdb>  args
# a = 5
# b = 10
# ipdb>  c
# 15

# %% [markdown]
# # Задание

# %% [markdown]
# Создайте любую функцию от нескольких аргументов и:

# %% [markdown]
# 1) Сделайте так, чтоб отладчик запускался из самой программы

# %% [markdown]
# 2) Выведите через отладчик:аргументы функции, ближайшие 10 строк относительно вашей позиции и весь код функции

# %% [markdown]
# 3) Создайте 2 точки останова
